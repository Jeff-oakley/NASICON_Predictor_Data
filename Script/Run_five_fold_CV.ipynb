# %% [markdown]
# # Evaluate linear boundary of synthesizability

# %% [markdown]
# With the optimal 2D SIS features, a linear boundary can effectively separate synthetically synthetically accessible and non-accessible NASICON compositions. This script is used to evaluate the performance of such linear classification model. Two sets of data splitting are used and the results are similar.
#
# 1. **80-20 validation**, with validation error demonstrated as peformance metric.  All data are split into a training set and a validation set with the ratio 80%: 20%. The 80-20 validation is used for selecting the 2D descriptors.
#
# 1. **five-fold cross-validation**, with average CV error demonstrated as performance metric. All data are partitioned into 5 subsets. In each round, 1 subset is used for validation and 4 subsets for training. The evaluation is performed in 5 rounds to make sure every subset is used as a validation set for once.
#
# * Note1: The Ehull value shows in the data are actually Ehull(1000K), this is calculated by Ehull(1000K) = Ehull(DFT) - S_ideal*1000K. The reason of doing that is because we use Ehull(1000K) to seperate GS/LS with US NASICONs.
# * Note 2: The same data can be reproduced with sklearn version 0.23.2. If you are using different version or have problem reproducing the 5-fold cross validation. You can use the *.dat files to reproduce the SVC model

# %% [markdown]
# **Input data with 2D SIS features:** RawData/train_2D.csv, RawData/test_2D.csv
# **Output:** validation errors from 80-20 splitting and 5-fold CV

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import pandas as pd
from pandas import DataFrame
import os
from sklearn.metrics import accuracy_score, f1_score, recall_score
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import LinearSVC,SVC
from copy import deepcopy
import json
from matplotlib import pyplot as plt
import scipy.special

from pymatgen.core.composition import Composition


prefix = os.getcwd()

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.23.2

# %% [markdown]
# ## Load data

# %%
# Note, the train test data here are from 80-20 data splitting. Which is used for SIS+MLR screening of 2D descriptors

train_2D_df = pd.read_csv('../RawData/train_2D.csv')
test_2D_df = pd.read_csv('../RawData/test_2D.csv')

# %%
train_2D_df.head()
# Out:
#        CompName      Ehull  (cbrt(NNaLst)+(AnionChgStdLst)^2)  \
# 0    MgZr(SO4)3 -60.260567                                0.0
# 1    MgTi(SO4)3 -27.986572                                0.0
# 2    MgSn(SO4)3 -30.640966                                0.0
# 3  Mg4Nb2(SO4)9 -42.783127                                0.0
# 4    ZrZn(SO4)3 -40.419098                                0.0
#
#    ((EWaldSumLst)^2*(XWithNaLst*RDiffStdLst))
# 0                                    0.000000
# 1                                  125.960243
# 2                                   46.109451
# 3                                   79.651306
# 4                                   24.253452

# %%
Ehull_train = train_2D_df['Ehull'].to_numpy()
Y_total = np.zeros_like(Ehull_train)
Y_total[np.where(Ehull_train<=0)] = 0
Y_total[np.where(Ehull_train>0)] = 1
X_total = train_2D_df[['(cbrt(NNaLst)+(AnionChgStdLst)^2)','((EWaldSumLst)^2*(XWithNaLst*RDiffStdLst))']].to_numpy()

Ehull_test = test_2D_df['Ehull'].to_numpy()
Y_valid = np.zeros_like(Ehull_test)
Y_valid[np.where(Ehull_test<=0)] = 0
Y_valid[np.where(Ehull_test>0)] = 1
X_valid = test_2D_df[['(cbrt(NNaLst)+(AnionChgStdLst)^2)','((EWaldSumLst)^2*(XWithNaLst*RDiffStdLst))']].to_numpy()
print(np.unique(Y_total),np.unique(Y_valid))
# Out:
# [0. 1.] [0. 1.]

# %% [markdown]
# ## Performance metric on 20% of the validation data (out of the training sample)

# %%
# The SVC validation error from 80-20 splitting

clf = SVC(kernel='linear',class_weight='balanced',probability=True)
clf.fit(X_total,Y_total)
Y_train_predict = clf.predict(X_total)
Y_valid_predict = clf.predict(X_valid)

train_score = accuracy_score(Y_total,Y_train_predict)
train_recall_avg = recall_score(Y_total,Y_train_predict,average='macro')
train_recall_LSGS = recall_score(Y_total,Y_train_predict,pos_label=0)
train_recall_US = recall_score(Y_total,Y_train_predict,pos_label=1)
train_F1_avg = f1_score(Y_total,Y_train_predict,average='macro')
train_F1_LSGS = f1_score(Y_total,Y_train_predict,pos_label=0)
train_F1_US = f1_score(Y_total,Y_train_predict,pos_label=1)
print('====================Train metrics==============================')
print(f'LSGS recall = {train_recall_LSGS}, US recall = {train_recall_US}')
print(f'LSGS F1 = {train_F1_LSGS}, US F1 = {train_F1_US}')
print(f'Accuracy = {train_score}, recall = {train_recall_avg}, F1 score = {train_F1_avg}')

test_score = accuracy_score(Y_valid,Y_valid_predict)
test_recall_avg = recall_score(Y_valid,Y_valid_predict,average='macro')
test_recall_LSGS = recall_score(Y_valid,Y_valid_predict,pos_label=0)
test_recall_US = recall_score(Y_valid,Y_valid_predict,pos_label=1)
test_F1_avg = f1_score(Y_valid,Y_valid_predict,average='macro')
test_F1_LSGS = f1_score(Y_valid,Y_valid_predict,pos_label=0)
test_F1_US = f1_score(Y_valid,Y_valid_predict,pos_label=1)

print('====================Test metrics==============================')
print(f'LSGS recall = {test_recall_LSGS}, US recall = {test_recall_US}')
print(f'LSGS F1 = {test_F1_LSGS}, US F1 = {test_F1_US}')
print(f'Accuracy = {test_score}, recall = {test_recall_avg}, F1 score = {test_F1_avg}')
# Out:
# ====================Train metrics==============================
# LSGS recall = 0.8576998050682261, US recall = 0.8216904670011579
# LSGS F1 = 0.6219081272084805, US F1 = 0.8883788858752346
# Accuracy = 0.8276417525773195, recall = 0.839695136034692, F1 score = 0.7551435065418576
# ====================Test metrics==============================
# LSGS recall = 0.796875, US recall = 0.8289676425269645
# LSGS F1 = 0.5982404692082111, US F1 = 0.8870568837592745
# Accuracy = 0.8236808236808236, recall = 0.8129213212634823, F1 score = 0.7426486764837428

# %% [markdown]
# ## Performance metric on five fold cross validation

# %%
skf = StratifiedKFold(n_splits=5,shuffle=True,random_state=0)

# %%
X_all_data = np.concatenate((X_total,X_valid))
Y_all_data = np.concatenate((Y_total,Y_valid))
ehull_all_data = np.concatenate((Ehull_train,Ehull_test))

# %%
print(Y_all_data.shape,X_all_data.shape)
# Out:
# (3881,) (3881, 2)

# %%
# The real train set = train set from skf + the validation data set
accuracy_lst, recall_lst, F1_lst, clf_lst, best_train_index_lst, best_test_index_lst, best_test_score_lst = \
    [], [], [], [], [], [], []

best_test_score = 0.0
count = 1

for train_index, test_index in skf.split(X_all_data,Y_all_data):
    print(f"============Performing fold {count}===================")
    X_train = X_all_data[train_index]
    X_test = X_all_data[test_index]
    Y_train = Y_all_data[train_index]
    Y_test = Y_all_data[test_index]
    
    clf = SVC(kernel='linear',class_weight='balanced',probability=True)

    clf.fit(X_train, Y_train)
    
    Y_train_predict = clf.predict(X_train)
    
    train_score = accuracy_score(Y_train,Y_train_predict)
    train_recall_avg = recall_score(Y_train,Y_train_predict,average='macro')
    train_recall_LSGS = recall_score(Y_train,Y_train_predict,pos_label=0)
    train_recall_US = recall_score(Y_train,Y_train_predict,pos_label=1)
    train_F1 = f1_score(Y_train,Y_train_predict,average='macro')
    train_F1_LSGS = f1_score(Y_train,Y_train_predict,pos_label=0)
    train_F1_US = f1_score(Y_train,Y_train_predict,pos_label=1)
    
    print('###Training metrics')
    print(f'LSGS recall = {train_recall_LSGS}, US recall = {train_recall_US}')
    print(f'LSGS F1 = {train_F1_LSGS}, US F1 = {train_F1_US}')
    print(f'Accuracy = {train_score}, average recall = {train_recall_avg}, average F1 score = {train_F1}')
    
    Y_cv_predict = clf.predict(X_test)

    test_score = accuracy_score(Y_test,Y_cv_predict)
    test_recall_avg = recall_score(Y_test,Y_cv_predict,average='macro')
    test_recall_LSGS = recall_score(Y_test,Y_cv_predict,pos_label=0)
    test_recall_US = recall_score(Y_test,Y_cv_predict,pos_label=1)
    test_F1 = f1_score(Y_test,Y_cv_predict,average='macro')
    test_F1_LSGS = f1_score(Y_test,Y_cv_predict,pos_label=0)
    test_F1_US = f1_score(Y_test,Y_cv_predict,pos_label=1)
    
    accuracy_lst.append(test_score)
    recall_lst.append(test_recall_avg)
    F1_lst.append(test_F1)
    clf_lst.append(deepcopy(clf))
    best_test_score_lst.append(test_score)
    best_train_index_lst.append(train_index)
    best_test_index_lst.append(test_index)
    
    print('###Testing metrics')
    print(f'LSGS recall = {test_recall_LSGS}, US recall = {test_recall_US}')
    print(f'LSGS F1 = {test_F1_LSGS}, US F1 = {test_F1_US}')
    print(f'Accuracy = {test_score}, average recall = {test_recall_avg}, average F1 score = {test_F1}')
    
    np.savetxt(f'train_X_fold{count}.dat',X_train)
    np.savetxt(f'test_X_fold{count}.dat',X_test)
    np.savetxt(f'train_Y_fold{count}.dat',Y_train)
    np.savetxt(f'test_Y_fold{count}.dat',Y_test)
        
    count += 1
    
print(f'Average accuracy = {np.average(accuracy_lst)}, recall = {np.average(recall_lst)}, F1 score = {np.average(F1_lst)}')
# Out:
# ============Performing fold 1===================
# ###Training metrics
# LSGS recall = 0.84375, US recall = 0.8148148148148148
# LSGS F1 = 0.6067415730337079, US F1 = 0.882943143812709
# Accuracy = 0.8195876288659794, average recall = 0.8292824074074074, average F1 score = 0.7448423584232085
# ###Testing metrics
# LSGS recall = 0.875968992248062, US recall = 0.8209876543209876
# LSGS F1 = 0.6312849162011173, US F1 = 0.8896321070234113
# Accuracy = 0.8301158301158301, average recall = 0.8484783232845248, average F1 score = 0.7604585116122643
# ============Performing fold 2===================
# ###Training metrics
# LSGS recall = 0.8596491228070176, US recall = 0.8209876543209876
# LSGS F1 = 0.6220028208744711, US F1 = 0.8881469115191987
# Accuracy = 0.8273752012882448, average recall = 0.8403183885640026, average F1 score = 0.755074866196835
# ###Testing metrics
# LSGS recall = 0.828125, US recall = 0.8024691358024691
# LSGS F1 = 0.5856353591160222, US F1 = 0.8739495798319329
# ...

# %%
# Select the best model that have F1 cloest to average F1 score

best_ind = 2
print(f'model {best_ind} is selected')
best_clf = clf_lst[best_ind]
best_train_index, best_test_index = best_train_index_lst[best_ind], best_test_index_lst[best_ind]
best_X_train, best_X_test = X_all_data[best_train_index,:], X_all_data[best_test_index,:]
best_Y_train, best_Y_test = Y_all_data[best_train_index], Y_all_data[best_test_index]
# Out:
# model 2 is selected

# %%
# Calculate the normalization factor to make sure the second feature dimensionaless

train_df = pd.read_csv('../RawData/train.csv')
test_df = pd.read_csv('../RawData/test.csv')

train_df = train_df.set_index('CompName')
test_df = test_df.set_index('CompName')

e_Ewald_ref = train_df.loc['Na3Zr2Si2PO12']['EWaldSumLst']
r_ref = 1.02 # The shannon radius of Na+

norm_factor = 1/(e_Ewald_ref**2*r_ref)
print(f'norm_factor is {norm_factor}')
# Out:
# norm_factor is 0.0005422912481778321

# %%
# print model coeffcient

print(best_clf.coef_)
print(best_clf.intercept_)
x_coeff = best_clf.coef_[0][0]*norm_factor/best_clf.coef_[0][1]
y_coeff = 1.0
intercept = -best_clf.intercept_[0]*norm_factor/best_clf.coef_[0][1]
print(f'{x_coeff}x+y<={intercept}')
# Out:
# [[3.54999016 0.00946628]]
# [-5.61898834]
# 0.2033670465699439x+y<=0.3218930226920147

# %% [markdown]
# ## Define functions that gonna be used for multiple times

# %%
def plot_ml_grid(clf,X_all_data):
    """
    Initialize the model grid
    """
    x_min, x_max = X_all_data[:,0].min()-0.5, X_all_data[:,0].max()+0.5
    y_min, y_max = X_all_data[:,1].min()-50, X_all_data[:,1].max()+100

    plot_stepx = (x_max-x_min)/500;
    plot_stepy = (y_max-y_min)/500;
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_stepx),
                         np.arange(y_min, y_max, plot_stepy))
    Z = best_clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.binary,alpha=0.2)

    
def pretty_plot():
    """
    Complete all the notations
    """
    _ = plt.yticks([0.00/norm_factor,0.10/norm_factor,0.20/norm_factor,0.30/norm_factor,0.40/norm_factor],
               [0.0,0.1,0.2,0.3,0.4])
    _ = plt.xticks(fontsize=24); plt.yticks(fontsize=24)
    plt.xlabel('$\sqrt[3]{N_{Na}}$+($Q_{A}^{Std}$)$^2$',fontsize=28)
    plt.ylabel(r'E$_{EWald}^2$$\cdot$X$_{M}^{Na}$$\cdot$R$_{M}^{Std}$',fontsize=28)
    plt.xlim((-0.5,2.8)) 
    plt.ylim((-30,780))
    plt.tight_layout()
    
    
def calc_prob(clf,X_test):
    """
    Be note that the default SVC.predict_proba is not correct even with normalization. Therefore we manually 
    calculate the probability according to definition of platt scale probability
    """
    decision_func = clf.decision_function(X_test)
    prob = 1 - 1/(1+np.exp(-decision_func))
    return prob

# %% [markdown]
# ## Plot all the data with the decision boundary that has highest validation accuracy/F1

# %%
plt.figure(figsize=(8,7))

ehull_train_arry = ehull_all_data[best_train_index]
ehull_test_arry = ehull_all_data[best_test_index]

plot_ml_grid(clf,X_all_data)
# plt.scatter(best_X_train[:,0],best_X_train[:,1],marker='o',s=[60 for i in range(ehull_train_arry.shape[0])],
#             c=ehull_train_arry,cmap='RdYlGn_r',vmin=-20,vmax=20,alpha=0.6)
# plt.scatter(best_X_test[:,0],best_X_test[:,1],marker='s',s=[60 for i in range(ehull_test_arry.shape[0])],
#             c=ehull_test_arry,edgecolors=['k' for i in range(ehull_train_arry.shape[0])],
#             cmap='RdYlGn_r',vmin=-20,vmax=20,alpha=0.8)
plt.scatter(best_X_train[:,0],best_X_train[:,1],marker='o',s=[60 for i in range(ehull_train_arry.shape[0])],
            c=ehull_train_arry,cmap='RdYlGn_r',vmin=-20,vmax=20,alpha=0.5,)
plt.scatter(best_X_test[:,0],best_X_test[:,1],marker='^',s=[90 for i in range(ehull_test_arry.shape[0])],
            c=ehull_test_arry,edgecolors=['k' for i in range(ehull_train_arry.shape[0])],
            cmap='RdYlGn_r',vmin=-20,vmax=20,alpha=0.8, linewidths=0.6)
CB=plt.colorbar()
CB.ax.tick_params(labelsize=24)
CB.set_ticks([-20,0,20]); CB.set_ticklabels(['-20','0','20'])
pretty_plot()
plt.savefig('Fig_5a.pdf')

# %% [markdown]
# ## plot experimentally reported NASICONs

# %%
import json

with open('../RawData/exp_comps.json','r') as fid:
    exp_comp_dict = json.load(fid)
    
reported_exp_comps = exp_comp_dict['reported_exp_comps']
new_exp_comps = exp_comp_dict['new_exp_comps']

all_comp_names = train_2D_df['CompName'].to_list() + test_2D_df['CompName'].tolist()

reported_exp_inds = [all_comp_names.index(exp_comp) for exp_comp in reported_exp_comps]
new_exp_inds = [all_comp_names.index(exp_comp) for exp_comp in new_exp_comps]

print(len(reported_exp_comps), len(new_exp_comps))
print(len(reported_exp_inds), len(new_exp_inds))
# Out:
# 27 5
# 27 5

# %%
plt.figure(figsize=(8,7))
plot_ml_grid(clf,X_all_data)

# plt.plot(X_all_data[reported_exp_inds,0],X_all_data[reported_exp_inds,1],'*',fillstyle='none',
#          color='k',markersize=30,label='Reported NASICON',alpha=1.0,markeredgewidth=2)
# plt.plot(X_all_data[new_exp_inds,0],X_all_data[new_exp_inds,1],'*',fillstyle='full',color='g',markersize=25,\
#          label='This Work',alpha=1.0,markeredgewidth=2)
plt.plot(X_all_data[reported_exp_inds,0],X_all_data[reported_exp_inds,1],'^',fillstyle='full',
         color='grey',markersize=23,label='Reported NASICON',alpha=0.3,markeredgewidth=1,markeredgecolor='k')
plt.plot(X_all_data[new_exp_inds,0],X_all_data[new_exp_inds,1],'v',fillstyle='full',color='g',markersize=25,\
         label='This Work',alpha=0.3,markeredgewidth=1,markeredgecolor='k')
pretty_plot()
plt.savefig('Fig_5b.pdf')

# %%
# Print the probability predicted by best model
# Be note that the default SVC.predict_proba is not correct even with normalization. Therefore we manually 
# calculate the probability according to definition of platt scale probability

flags = ['Yes','No']
fn_prob_lst = []
for exp_ind in reported_exp_inds + new_exp_inds:
    comp_name = all_comp_names[exp_ind]
    
    flag = flags[int(best_clf.predict(X_all_data[[exp_ind]])[0])]
    prob = calc_prob(best_clf,X_all_data[[exp_ind]])[0]
    print(f'{comp_name}\t{prob:.3f}\t{flag}')
    
    if flag == 'No':
        fn_prob_lst.append(prob)
print(f'Average probabiliy for false negative cases {np.average(fn_prob_lst)}')
# Out:
# Na3Zr2Si2PO12	0.428	No
# Na4Zr2(SiO4)3	0.496	No
# NaTi2(PO4)3	0.888	Yes
# NaSn2(PO4)3	0.888	Yes
# NaHf2(PO4)3	0.888	Yes
# Na3MgZr(PO4)3	0.622	Yes
# Na2Zr2Si(PO6)2	0.588	Yes
# Na3ZrTiSi2PO12	0.310	No
# Na3Ti2Si2PO12	0.428	No
# Na3Sc2(PO4)3	0.622	Yes
# Na3ZrZn(PO4)3	0.596	Yes
# Na3Hf2Si2PO12	0.428	No
# Na3Y2(PO4)3	0.622	Yes
# Na4HfAlSi2PO12	0.185	No
# NaAlZn(SO4)3	0.387	No
# NaMgAl(SO4)3	0.583	Yes
# NaZnIn(SO4)3	0.778	Yes
# NaMgIn(SO4)3	0.772	Yes
# Na3HfTiSi2PO12	0.322	No
# NaGe2(PO4)3	0.888	Yes
# NaTiGe(PO4)3	0.760	Yes
# NaTiSn(PO4)3	0.748	Yes
# NaZrSn(PO4)3	0.855	Yes
# Na2ZrAl(PO4)3	0.493	No
# Na3In2(PO4)3	0.622	Yes
# NaZr2(PO4)3	0.888	Yes
# Na3Al2(PO4)3	0.622	Yes
# Na3HfZrSi2PO12	0.420	No
# Na6Hf3MgSi2(PO6)4	0.421	No
# Na3HfScSi(PO6)2	0.397	No
# Na6CaHf3Si2(PO6)4	0.274	No
# Na6MgZr3Si2(PO6)4	0.428	No
# Average probabiliy for false negative cases 0.3869109103176539

# %%
# Zoom in the five newly synthesized compounds

plt.figure(figsize=(8,5))
plot_ml_grid(clf,X_all_data)
# plt.plot(X_all_data[reported_exp_inds,0],X_all_data[reported_exp_inds,1],'^',fillstyle='full',color='k',markersize=36,label='Reported NASICON',\
#          alpha=0.3,markeredgewidth=2)
# plt.plot(X_all_data[new_exp_inds,0],X_all_data[new_exp_inds,1],'v',fillstyle='full',color='g',markersize=36,\
#          label='This Work',alpha=0.3,markeredgewidth=2,markeredgecolor='g')
plt.plot(X_all_data[reported_exp_inds,0],X_all_data[reported_exp_inds,1],'^',fillstyle='full',color='darkgray',markersize=48,label='Reported NASICON',\
         alpha=0.3,markeredgewidth=2,markeredgecolor='k')
plt.plot(X_all_data[new_exp_inds,0],X_all_data[new_exp_inds,1],'v',fillstyle='full',color='g',markersize=48,\
         label='This Work',alpha=0.3,markeredgewidth=2,markeredgecolor='k')
plt.xlim((1.62,1.72)); plt.ylim((-3,18));
plt.xticks([1.65,1.7],[1.65,1.7],fontsize=24);
plt.yticks([0.00/norm_factor,0.004/norm_factor,0.008/norm_factor],
           [0.0,0.004,0.008],fontsize=24)
plt.tight_layout()
plt.savefig('Fig_5b_zoom.pdf')

# %% [markdown]
# ## plot Na rich and Na poor NASICONs

# %%
def obtain_NNa(comp_lst):
    NNa_lst = []
    for reduced_formula in comp_lst:
        NNa = Composition(reduced_formula)['Na']/Composition(reduced_formula)['O']*12.0
        NNa_lst.append(NNa)
        
    return np.array(NNa_lst)

ehull_train_arry = ehull_all_data[best_train_index]
ehull_test_arry = ehull_all_data[best_test_index]
train_comp_names = [all_comp_names[i] for i in best_train_index]
test_comp_names = [all_comp_names[i] for i in best_test_index]

NNa_train_arry = obtain_NNa(train_comp_names)
NNa_test_arry = obtain_NNa(test_comp_names)

NaPoor_LSGS_train_inds = np.where((NNa_train_arry<=1.0) & (ehull_train_arry<=0))[0]
NaRich_LSGS_train_inds = np.where((NNa_train_arry>=3.0) & (ehull_train_arry<=0))[0]
NaPoor_LSGS_test_inds = np.where((NNa_test_arry<=1.0) & (ehull_test_arry<=0))[0]
NaRich_LSGS_test_inds = np.where((NNa_test_arry>=3.0) & (ehull_test_arry<=0))[0]

# %%
# The weighted ratio

NaPoor_LSGS_train_proba = calc_prob(best_clf,best_X_train[NaPoor_LSGS_train_inds])
NaRich_LSGS_train_proba = calc_prob(best_clf,best_X_train[NaRich_LSGS_train_inds])
NaPoor_LSGS_test_proba = calc_prob(best_clf,best_X_test[NaPoor_LSGS_test_inds])
NaRich_LSGS_test_proba = calc_prob(best_clf,best_X_test[NaRich_LSGS_test_inds])

print(
    NaPoor_LSGS_train_proba.shape, NaRich_LSGS_train_proba.shape, \
    NaPoor_LSGS_test_proba.shape, NaRich_LSGS_test_proba.shape, \
    len(NaPoor_LSGS_train_inds), len(NaRich_LSGS_train_inds), \
    len(NaPoor_LSGS_test_inds), len(NaRich_LSGS_test_inds)
      )
# Out:
# (363,) (48,) (91,) (12,) 363 48 91 12

# %%
plt.figure(figsize=(8,7))

plot_ml_grid(clf,X_all_data)
plt.scatter(best_X_train[NaPoor_LSGS_train_inds,0],best_X_train[NaPoor_LSGS_train_inds,1],cmap='pink_r',marker='o',
         s=210,c=NaPoor_LSGS_train_proba,edgecolors=['g' for _ in range(len(NaPoor_LSGS_test_inds))],alpha=0.4,
            vmin=0.0,vmax=1.0)
plt.scatter(best_X_train[NaRich_LSGS_train_inds,0],best_X_train[NaRich_LSGS_train_inds,1],cmap='pink_r',marker='^',
         s=210,c=NaRich_LSGS_train_proba,edgecolors=['g' for _ in range(len(NaPoor_LSGS_test_inds))],alpha=0.4,
            vmin=0.0,vmax=1.0)
plt.scatter(best_X_test[NaPoor_LSGS_test_inds,0],best_X_test[NaPoor_LSGS_test_inds,1],cmap='pink_r',marker='o',
         s=210,c=NaPoor_LSGS_test_proba,edgecolors=['k' for _ in range(len(NaPoor_LSGS_test_inds))],alpha=0.8,
         vmin=0.0,vmax=1.0)
plt.scatter(best_X_test[NaRich_LSGS_test_inds,0],best_X_test[NaRich_LSGS_test_inds,1],cmap='pink_r',marker='^',
         s=210,c=NaRich_LSGS_test_proba,edgecolors=['k' for _ in range(len(NaRich_LSGS_test_inds))],alpha=0.8,
         vmin=0.0,vmax=1.0)
CB=plt.colorbar()
CB.ax.tick_params(labelsize=24)
pretty_plot()
plt.savefig('Fig_5c.pdf')

# %%
NaPoor_train_inds = np.where((NNa_train_arry<=1.0))[0]
NaRich_train_inds = np.where((NNa_train_arry>=3.0))[0]
NaPoor_test_inds = np.where((NNa_test_arry<=1.0))[0]
NaRich_test_inds = np.where((NNa_test_arry>=3.0))[0]

ratio =  best_clf.class_weight_/best_clf.class_weight_.sum()
NaPoor_train_proba = calc_prob(best_clf,best_X_train[NaPoor_train_inds])
NaRich_train_proba = calc_prob(best_clf,best_X_train[NaRich_train_inds])
NaPoor_test_proba = calc_prob(best_clf,best_X_test[NaPoor_test_inds])
NaRich_test_proba = calc_prob(best_clf,best_X_test[NaRich_test_inds])

plt.figure(figsize=(8,7))
plot_ml_grid(clf,X_all_data)

ehull_train_arry = ehull_all_data[best_train_index]
ehull_test_arry = ehull_all_data[best_test_index]

plt.scatter(best_X_train[NaPoor_train_inds,0],best_X_train[NaPoor_train_inds,1],cmap='pink_r',marker='o',
         s=210,c=NaPoor_train_proba,edgecolors=['g' for _ in range(len(NaPoor_train_proba))],alpha=0.4,
            vmin=0.0,vmax=1.0)
plt.scatter(best_X_train[NaRich_train_inds,0],best_X_train[NaRich_train_inds,1],cmap='pink_r',marker='^',
         s=210,c=NaRich_train_proba,edgecolors=['g' for _ in range(len(NaRich_train_proba))],alpha=0.4,
            vmin=0.0,vmax=1.0)
plt.scatter(best_X_test[NaPoor_test_inds,0],best_X_test[NaPoor_test_inds,1],cmap='pink_r',marker='o',
         s=210,c=NaPoor_test_proba,edgecolors=['k' for _ in range(len(NaPoor_LSGS_test_inds))],alpha=0.8,
         vmin=0.0,vmax=1.0)
plt.scatter(best_X_test[NaRich_test_inds,0],best_X_test[NaRich_test_inds,1],cmap='pink_r',marker='^',
         s=210,c=NaRich_test_proba,edgecolors=['k' for _ in range(len(NaRich_LSGS_test_inds))],alpha=0.8,
         vmin=0.0,vmax=1.0)
CB=plt.colorbar()
CB.ax.tick_params(labelsize=24)
pretty_plot()
plt.savefig('Fig_S6a.pdf')

# %%
# Print the probability predicted by best model
# Be note that the default SVC.predict_proba is not correct even with normalization. Therefore we manually 
# calculate the probability according to definition of platt scale probability

flags = ['Yes','No']

fn_prob_lst = []
for test_ind in NaRich_LSGS_test_inds:
    prob = calc_prob(best_clf,best_X_test[[test_ind]])[0]
    flag = flags[int(best_clf.predict(best_X_test[[test_ind]])[0])]
    if flag == 'No':
        fn_prob_lst.append(prob)
print(f'Average probabiliy for false negative cases is {np.average(fn_prob_lst)}')
    
fn_prob_lst = []
for test_ind in NaPoor_LSGS_test_inds:
    prob = calc_prob(best_clf,best_X_test[[test_ind]])[0]
    flag = flags[int(best_clf.predict(best_X_test[[test_ind]])[0])]
    if flag == 'No':
        fn_prob_lst.append(prob)
print(f'Average probabiliy for false negative cases is {np.average(fn_prob_lst)}')
# Out:
# Average probabiliy for false negative cases is 0.3773401569965421
# Average probabiliy for false negative cases is 0.30431780342008447

# %%
Na_Poor_LSGS_predict = best_clf.predict(best_X_test[NaPoor_LSGS_test_inds,:])
Na_Poor_LSGS_recall = recall_score(best_Y_test[NaPoor_LSGS_test_inds],Na_Poor_LSGS_predict,pos_label=0)
Na_Poor_LSGS_f1 = f1_score(best_Y_test[NaPoor_LSGS_test_inds],Na_Poor_LSGS_predict,pos_label=0)
print(Na_Poor_LSGS_predict.shape)

Na_Rich_LSGS_predict = best_clf.predict(best_X_test[NaRich_LSGS_test_inds,:])
Na_Rich_LSGS_recall = recall_score(best_Y_test[NaRich_LSGS_test_inds],Na_Rich_LSGS_predict,pos_label=0)
Na_Rich_LSGS_f1 = f1_score(best_Y_test[NaRich_LSGS_test_inds],Na_Rich_LSGS_predict,pos_label=0)
print(Na_Rich_LSGS_predict.shape)

Na_Poor_LSGS_train_predict = best_clf.predict(best_X_train[NaPoor_LSGS_train_inds,:])
Na_Poor_LSGS_train_recall = recall_score(best_Y_train[NaPoor_LSGS_train_inds],Na_Poor_LSGS_train_predict,pos_label=0)
Na_Poor_LSGS_train_f1 = f1_score(best_Y_train[NaPoor_LSGS_train_inds],Na_Poor_LSGS_train_predict,pos_label=0)
print(Na_Poor_LSGS_train_predict.shape)

Na_Rich_LSGS_train_predict = best_clf.predict(best_X_train[NaRich_LSGS_train_inds,:])
Na_Rich_LSGS_train_recall = recall_score(best_Y_train[NaRich_LSGS_train_inds],Na_Rich_LSGS_train_predict,pos_label=0)
Na_Rich_LSGS_train_f1 = f1_score(best_Y_train[NaRich_LSGS_train_inds],Na_Rich_LSGS_train_predict,pos_label=0)
print(Na_Rich_LSGS_train_predict.shape)


print(f'###Training metrics')
print(f'Na_Poor_LSGS_recall={Na_Poor_LSGS_train_recall}, Na_Rich_LSGS_recall={Na_Rich_LSGS_train_recall}')
print(f'Na_Poor_LSGS_f1 = {Na_Poor_LSGS_train_f1}, Na_Rich_LSGS_f1={Na_Rich_LSGS_train_f1}')
print(f'###Testing metrics')
print(f'Na_Poor_LSGS_recall={Na_Poor_LSGS_recall}, Na_Rich_LSGS_recall={Na_Rich_LSGS_recall}')
print(f'Na_Poor_LSGS_f1 = {Na_Poor_LSGS_f1}, Na_Rich_LSGS_f1={Na_Rich_LSGS_f1}')
# Out:
# (91,)
# (12,)
# (363,)
# (48,)
# ###Training metrics
# Na_Poor_LSGS_recall=0.9338842975206612, Na_Rich_LSGS_recall=0.25
# Na_Poor_LSGS_f1 = 0.9658119658119658, Na_Rich_LSGS_f1=0.4
# ###Testing metrics
# Na_Poor_LSGS_recall=0.8791208791208791, Na_Rich_LSGS_recall=0.25
# Na_Poor_LSGS_f1 = 0.935672514619883, Na_Rich_LSGS_f1=0.4

# %% [markdown]
# ## plot Ca/Ge and Hf/Zr NASICONs

# %%
def obtain_NASICON_with_metal(comp_lst,ehull_arry,metals):
    NASICON_comp_lst, NASICON_comp_inds = [], []
    for i, reduced_formula in enumerate(comp_lst):
        NM = 0.0
        for metal in metals:
            NM += Composition(reduced_formula)[metal]/Composition(reduced_formula)['O']*12.0
        if NM > 0.0 and ehull_arry[i] <= 0:
            NASICON_comp_lst.append(reduced_formula)
            NASICON_comp_inds.append(i)
        
    return NASICON_comp_lst, NASICON_comp_inds


ehull_train_arry = ehull_all_data[best_train_index]
ehull_test_arry = ehull_all_data[best_test_index]
train_comp_names = [all_comp_names[i] for i in best_train_index]
test_comp_names = [all_comp_names[i] for i in best_test_index]

CaGe_train_comps, CaGe_train_inds = obtain_NASICON_with_metal(train_comp_names, ehull_train_arry, ['Ca','Ge'])
CaGe_test_comps, CaGe_test_inds = obtain_NASICON_with_metal(test_comp_names, ehull_test_arry, ['Ca','Ge'])
HfZr_train_comps, HfZr_train_inds = obtain_NASICON_with_metal(train_comp_names, ehull_train_arry, ['Hf','Zr'])
HfZr_test_comps, HfZr_test_inds = obtain_NASICON_with_metal(test_comp_names, ehull_test_arry, ['Hf','Zr'])

# %%
# The weighted ratio

CaGe_LSGS_train_proba = calc_prob(best_clf,best_X_train[CaGe_train_inds])
HfZr_LSGS_train_proba = calc_prob(best_clf,best_X_train[HfZr_train_inds])
CaGe_LSGS_test_proba = calc_prob(best_clf,best_X_test[CaGe_test_inds])
HfZr_LSGS_test_proba = calc_prob(best_clf,best_X_test[HfZr_test_inds])

# %%
# The weighted ratio

# Print the probability predicted by best model
flags = ['Yes','No']
ratio = best_clf.class_weight_/best_clf.class_weight_.sum()

fn_prob_lst = []
for test_ind in CaGe_test_inds:
    prob = calc_prob(best_clf,best_X_test[[test_ind]])[0]
    flag = flags[int(best_clf.predict(best_X_test[[test_ind]])[0])]
    if flag == 'No':
        fn_prob_lst.append(prob)
    prob = best_clf.predict_proba(best_X_test[[test_ind]])[0]

print(f'Average probabiliy for false negative cases is {np.average(fn_prob_lst)}')

fn_prob_lst = []
for test_ind in HfZr_test_inds:
    prob = calc_prob(best_clf,best_X_test[[test_ind]])[0]
    flag = flags[int(best_clf.predict(best_X_test[[test_ind]])[0])]
    if flag == 'No':
        fn_prob_lst.append(prob)
    prob = best_clf.predict_proba(best_X_test[[test_ind]])[0]

print(f'Average probabiliy for false negative cases is {np.average(fn_prob_lst)}')
# Out:
# Average probabiliy for false negative cases is 0.342968862133004
# Average probabiliy for false negative cases is 0.3396321694287867

# %%
CaGe_LSGS_train_predict = best_clf.predict(best_X_train[CaGe_train_inds,:])
CaGe_LSGS_train_recall = recall_score(best_Y_train[CaGe_train_inds],CaGe_LSGS_train_predict,pos_label=0)
CaGe_LSGS_train_f1 = f1_score(best_Y_train[CaGe_train_inds],CaGe_LSGS_train_predict,pos_label=0)
print(CaGe_LSGS_train_predict.shape)

HfZr_LSGS_train_predict = best_clf.predict(best_X_train[HfZr_train_inds,:])
HfZr_LSGS_train_recall = recall_score(best_Y_train[HfZr_train_inds],HfZr_LSGS_train_predict,pos_label=0)
HfZr_LSGS_train_f1 = f1_score(best_Y_train[HfZr_train_inds],HfZr_LSGS_train_predict,pos_label=0)
print(HfZr_LSGS_train_predict.shape)

print(f'###Testing metrics')
print(f'CaGe_LSGS_recall={CaGe_LSGS_train_recall}, HfZr_LSGS_recall={HfZr_LSGS_train_recall}')
print(f'CaGe_LSGS_f1 = {CaGe_LSGS_train_f1}, HfZr_LSGS_f1={HfZr_LSGS_train_f1}')


CaGe_LSGS_predict = best_clf.predict(best_X_test[CaGe_test_inds,:])
CaGe_LSGS_recall = recall_score(best_Y_test[CaGe_test_inds],CaGe_LSGS_predict,pos_label=0)
CaGe_LSGS_f1 = f1_score(best_Y_test[CaGe_test_inds],CaGe_LSGS_predict,pos_label=0)
print(CaGe_LSGS_predict.shape)

HfZr_LSGS_predict = best_clf.predict(best_X_test[HfZr_test_inds,:])
HfZr_LSGS_recall = recall_score(best_Y_test[HfZr_test_inds],HfZr_LSGS_predict,pos_label=0)
HfZr_LSGS_f1 = f1_score(best_Y_test[HfZr_test_inds],HfZr_LSGS_predict,pos_label=0)
print(HfZr_LSGS_predict.shape)

print(f'###Testing metrics')
print(f'CaGe_LSGS_recall={CaGe_LSGS_recall}, HfZr_LSGS_recall={HfZr_LSGS_recall}')
print(f'CaGe_LSGS_f1 = {CaGe_LSGS_f1}, HfZr_LSGS_f1={HfZr_LSGS_f1}')
# Out:
# (60,)
# (191,)
# ###Testing metrics
# CaGe_LSGS_recall=0.7333333333333333, HfZr_LSGS_recall=0.7539267015706806
# CaGe_LSGS_f1 = 0.846153846153846, HfZr_LSGS_f1=0.8597014925373135
# (11,)
# (49,)
# ###Testing metrics
# CaGe_LSGS_recall=0.7272727272727273, HfZr_LSGS_recall=0.6938775510204082
# CaGe_LSGS_f1 = 0.8421052631578948, HfZr_LSGS_f1=0.819277108433735

# %%
plt.figure(figsize=(8,7))
plot_ml_grid(clf,X_all_data)
plt.scatter(best_X_train[CaGe_train_inds,0],best_X_train[CaGe_train_inds,1],cmap='pink_r',marker='o',
         s=210,c=CaGe_LSGS_train_proba,edgecolors=['g' for _ in range(len(CaGe_train_inds))],alpha=0.4,
            vmin=0.0,vmax=1.0)
plt.scatter(best_X_train[CaGe_test_inds,0],best_X_train[CaGe_test_inds,1],cmap='pink_r',marker='^',
         s=210,c=CaGe_LSGS_test_proba,edgecolors=['g' for _ in range(len(CaGe_test_inds))],alpha=0.4,
            vmin=0.0,vmax=1.0)
plt.scatter(best_X_train[HfZr_train_inds,0],best_X_train[HfZr_train_inds,1],cmap='pink_r',marker='o',
         s=210,c=HfZr_LSGS_train_proba,edgecolors=['k' for _ in range(len(HfZr_train_inds))],alpha=0.8,
         vmin=0.0,vmax=1.0)
plt.scatter(best_X_test[HfZr_test_inds,0],best_X_test[HfZr_test_inds,1],cmap='pink_r',marker='^',
         s=210,c=HfZr_LSGS_test_proba,edgecolors=['k' for _ in range(len(HfZr_test_inds))],alpha=0.8,
         vmin=0.0,vmax=1.0)
CB=plt.colorbar()
CB.ax.tick_params(labelsize=24)
pretty_plot()
plt.savefig('Fig_5d.pdf')

# %%
def obtain_NASICON_with_metal2(comp_lst,ehull_arry,metals):
    NASICON_comp_lst, NASICON_comp_inds = [], []
    for i, reduced_formula in enumerate(comp_lst):
        NM = 0.0
        for metal in metals:
            NM += Composition(reduced_formula)[metal]/Composition(reduced_formula)['O']*12.0
        if NM > 0.0:
            NASICON_comp_lst.append(reduced_formula)
            NASICON_comp_inds.append(i)
        
    return NASICON_comp_lst, NASICON_comp_inds


ehull_train_arry = ehull_all_data[best_train_index]
ehull_test_arry = ehull_all_data[best_test_index]
train_comp_names = [all_comp_names[i] for i in best_train_index]
test_comp_names = [all_comp_names[i] for i in best_test_index]

CaGe_train_comps, CaGe_train_inds = obtain_NASICON_with_metal2(train_comp_names, ehull_train_arry, ['Ca','Ge'])
CaGe_test_comps, CaGe_test_inds = obtain_NASICON_with_metal2(test_comp_names, ehull_test_arry, ['Ca','Ge'])
HfZr_train_comps, HfZr_train_inds = obtain_NASICON_with_metal2(train_comp_names, ehull_train_arry, ['Hf','Zr'])
HfZr_test_comps, HfZr_test_inds = obtain_NASICON_with_metal2(test_comp_names, ehull_test_arry, ['Hf','Zr'])

CaGe_LSGS_train_proba = calc_prob(best_clf,best_X_train[CaGe_train_inds])
HfZr_LSGS_train_proba = calc_prob(best_clf,best_X_train[HfZr_train_inds])
CaGe_LSGS_test_proba = calc_prob(best_clf,best_X_test[CaGe_test_inds])
HfZr_LSGS_test_proba = calc_prob(best_clf,best_X_test[HfZr_test_inds])

plt.figure(figsize=(8,7))
plot_ml_grid(clf,X_all_data)
plt.scatter(best_X_train[CaGe_train_inds,0],best_X_train[CaGe_train_inds,1],cmap='pink_r',marker='o',
         s=210,c=CaGe_LSGS_train_proba,edgecolors=['g' for _ in range(len(CaGe_train_inds))],alpha=0.4,
            vmin=0.0,vmax=1.0)
plt.scatter(best_X_train[CaGe_test_inds,0],best_X_train[CaGe_test_inds,1],cmap='pink_r',marker='^',
         s=210,c=CaGe_LSGS_test_proba,edgecolors=['g' for _ in range(len(CaGe_test_inds))],alpha=0.4,
            vmin=0.0,vmax=1.0)
plt.scatter(best_X_train[HfZr_train_inds,0],best_X_train[HfZr_train_inds,1],cmap='pink_r',marker='o',
         s=210,c=HfZr_LSGS_train_proba,edgecolors=['k' for _ in range(len(HfZr_train_inds))],alpha=0.8,
         vmin=0.0,vmax=1.0)
plt.scatter(best_X_test[HfZr_test_inds,0],best_X_test[HfZr_test_inds,1],cmap='pink_r',marker='^',
         s=210,c=HfZr_LSGS_test_proba,edgecolors=['k' for _ in range(len(HfZr_test_inds))],alpha=0.8,
         vmin=0.0,vmax=1.0)
CB=plt.colorbar()
CB.ax.tick_params(labelsize=24)
pretty_plot()
plt.savefig('Fig_S6b.pdf')

# %% [markdown]
# ## Plot probability distribution

# %%
from seaborn import distplot

ehull_train_arry = ehull_all_data[best_train_index]
ehull_test_arry = ehull_all_data[best_test_index]

best_X_train_LSGS, best_X_train_US = best_X_train[ehull_train_arry<=0], best_X_train[ehull_train_arry>0]
best_X_test_LSGS, best_X_test_US = best_X_test[ehull_test_arry<=0], best_X_test[ehull_test_arry>0]

prob_train_LSGS = calc_prob(best_clf,best_X_train_LSGS)
prob_train_US = calc_prob(best_clf,best_X_train_US)
prob_test_LSGS = calc_prob(best_clf,best_X_test_LSGS)
prob_test_US = calc_prob(best_clf,best_X_test_US)


fig=plt.figure(figsize=(8,10))
plt.subplot(211)
distplot(np.concatenate((prob_train_US,prob_test_US)),bins=50,kde=False,color='red',label='US NASICONs')
plt.xticks([])
plt.yticks([0,100,200,300,400],[0,100,200,300,400],fontsize=24)
plt.ylabel('Count',fontsize=24)
plt.legend(fontsize=18,loc='upper left')

plt.subplot(212)
distplot(np.concatenate((prob_train_LSGS,prob_test_LSGS)),bins=50,kde=False,color='green',label='GS/LS NASICONs')
plt.xticks(fontsize=24)
plt.yticks([0,20,40,60,80],[0,20,40,60,80],fontsize=24)
plt.xlabel('P$_{accessible}$',fontsize=24)
plt.ylabel('Count',fontsize=24)
plt.legend(fontsize=18,loc='upper left')
plt.tight_layout()
plt.savefig('Fig_S5a.pdf')

# %%
plt.figure(figsize=(8,7))

x_min, x_max = X_all_data[:,0].min()-0.5, X_all_data[:,0].max()+0.5
y_min, y_max = X_all_data[:,1].min()-50, X_all_data[:,1].max()+100
plot_stepx = (x_max-x_min)/500;
plot_stepy = (y_max-y_min)/500;
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_stepx),
                     np.arange(y_min, y_max, plot_stepy))
Z = best_clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.binary,alpha=0.2)
# plot_stepx = (x_max-x_min)/500;
# plot_stepy = (y_max-y_min)/500;
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_stepx),
                     np.arange(y_min, y_max, plot_stepy))
prob_arry = calc_prob(best_clf,np.c_[xx.ravel(), yy.ravel()])
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.binary,alpha=0.2)
plt.scatter(best_X_train[:,0],best_X_train[:,1],marker='o',s=[60 for i in range(ehull_train_arry.shape[0])],
            c=ehull_train_arry,cmap='RdYlGn_r',vmin=-20,vmax=20,alpha=0.5,)
plt.scatter(best_X_test[:,0],best_X_test[:,1],marker='^',s=[90 for i in range(ehull_test_arry.shape[0])],
            c=ehull_test_arry,edgecolors=['k' for i in range(ehull_train_arry.shape[0])],
            cmap='RdYlGn_r',vmin=-20,vmax=20,alpha=0.8, linewidths=0.6)
CB=plt.colorbar()
CB.ax.tick_params(labelsize=24)
CB.set_ticks([-20,0,20]); CB.set_ticklabels(['-20','0','20'])
CS = plt.contour(xx, yy, prob_arry.reshape(xx.shape),colors=['black'])
plt.clabel(CS, inline=True, fontsize=18,inline_spacing=0.5)
pretty_plot()
plt.savefig('Fig_S5b.pdf')
